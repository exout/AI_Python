# %%
import pandas as pd

# %%
df = pd.read_csv('Data/test/analysis-stock-change-5-quoted.csv', quotechar='|')

# %%
df.head()
# Out:
#                                                 text  stock_change  compound  \
# 0  AAK AB: AAK förväntar sig ett rörelseresultat ...          5.87    0.0000
# 1  AAK AB: AAK:s delårsrapport för det andra kvar...         -7.47    0.5574
# 2  AAK AB: AAK:s delårsrapport för det första kva...         -5.01    0.0000
# 3  Nya prekliniska data kring tasquinimod kommer ...         10.65    0.0000
# 4  Active Biotech Delårsrapport januari - septemb...         10.65    0.0000
#
#    neg    neu    pos
# 0  0.0  1.000  0.000
# 1  0.0  0.796  0.204
# 2  0.0  1.000  0.000
# 3  0.0  1.000  0.000
# 4  0.0  1.000  0.000

# %%
df.dtypes
# Out:
# text             object
# stock_change    float64
# compound        float64
# neg             float64
# neu             float64
# pos             float64
# dtype: object

# %%
df.columns
# Out:
# Index(['text', 'stock_change', 'compound', 'neg', 'neu', 'pos'], dtype='object')

# %%
df[df['stock_change'] >= 5]
df
# Out:
#                                                     text  stock_change  \
# 0      AAK AB: AAK förväntar sig ett rörelseresultat ...          5.87
# 1      AAK AB: AAK:s delårsrapport för det andra kvar...         -7.47
# 2      AAK AB: AAK:s delårsrapport för det första kva...         -5.01
# 3      Nya prekliniska data kring tasquinimod kommer ...         10.65
# 4      Active Biotech Delårsrapport januari - septemb...         10.65
# ...                                                  ...           ...
# 15896  Storskogen Group AB: Första dag för handel i S...         31.17
# 15897  Ändring av antal aktier och röster i Truecalle...         -5.16
# 15898  Truecaller AB: Truecaller samarbetar med India...         23.16
# 15899  Truecaller AB: Tredje kvartalet 2021: Truecall...         33.84
# 15900  Nordisk Bergteknik AB: Meddelande om stabilise...         19.69
#
#        compound    neg    neu    pos
# 0        0.0000  0.000  1.000  0.000
# 1        0.5574  0.000  0.796  0.204
# ...
